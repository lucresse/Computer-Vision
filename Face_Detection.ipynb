# %% [markdown]
# # Face Detection
#
# Hello! In this task you will create your own deep face detector.
#
# First of all, we need import some useful stuff.

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Do you have modern Nvidia [GPU](https://en.wikipedia.org/wiki/Graphics_processing_unit)? There is your video-card model in [list](https://developer.nvidia.com/cuda-gpus) and CUDA capability >= 3.0?
#
# - Yes. You can use it for fast deep learning! In this work we recommend you use tensorflow backend with GPU. Read [installation notes](https://www.tensorflow.org/install/) with attention to gpu section, install all requirements and then install GPU version `tensorflow-gpu`.
# - No. CPU is enough for this task, but you have to use only simple model. Read [installation notes](https://www.tensorflow.org/install/) and install CPU version `tensorflow`.
#
# Of course, also you should install `keras`, `matplotlib`, `numpy` and `scikit-image`.

# %%
from keras import backend as K
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from matplotlib import pyplot as plt
import numpy as np
from skimage import transform

# %%
# !unzip /content/Face-detection-task.zip
# Out:
# Archive:  /content/Face-detection-task.zip
#    creating: face-detection/
#    creating: face-detection/.git/
#    creating: face-detection/.git/refs/
#    creating: face-detection/.git/refs/heads/
#  extracting: face-detection/.git/refs/heads/master
#    creating: face-detection/.git/refs/tags/
#  extracting: face-detection/.git/refs/tags/v1.3
#    creating: face-detection/.git/refs/remotes/
#    creating: face-detection/.git/refs/remotes/origin/
#  extracting: face-detection/.git/refs/remotes/origin/HEAD
#  extracting: face-detection/.git/refs/remotes/origin/master
#    creating: face-detection/.git/info/
#   inflating: face-detection/.git/info/exclude
#    creating: face-detection/.git/hooks/
#   inflating: face-detection/.git/hooks/pre-commit.sample
#   inflating: face-detection/.git/hooks/pre-applypatch.sample
#   inflating: face-detection/.git/hooks/prepare-commit-msg.sample
#   inflating: face-detection/.git/hooks/commit-msg.sample
#   inflating: face-detection/.git/hooks/pre-rebase.sample
#   inflating: face-detection/.git/hooks/pre-push.sample
#   inflating: face-detection/.git/hooks/update.sample
#   inflating: face-detection/.git/hooks/applypatch-msg.sample
#   inflating: face-detection/.git/hooks/post-update.sample
#    creating: face-detection/.git/branches/
#   inflating: face-detection/.git/description
#    creating: face-detection/.git/objects/
#    creating: face-detection/.git/objects/pack/
#   inflating: face-detection/.git/objects/pack/pack-24093349c326feb19acdcf8d5f8518df92f71664.pack
#   inflating: face-detection/.git/objects/pack/pack-24093349c326feb19acdcf8d5f8518df92f71664.idx
#    creating: face-detection/.git/objects/info/
#    creating: face-detection/.git/objects/8c/
#  extracting: face-detection/.git/objects/8c/1aa50a0fc8c7331b03a430e63cb598679c011b
#    creating: face-detection/.git/objects/59/
#  extracting: face-detection/.git/objects/59/f4fcaead604931c611c76c99570fe7b85146c7
#    creating: face-detection/.git/objects/42/
#  extracting: face-detection/.git/objects/42/b3e9720b0c8ca63de07304d9c11da6487bed3f
#    creating: face-detection/.git/objects/00/
#  extracting: face-detection/.git/objects/00/e1338c4303d17cc3030d42a0bfc8ea5f5e0e8f
#    creating: face-detection/.git/objects/a1/
#  extracting: face-detection/.git/objects/a1/a67f0a1de08606d7a1e7911421ad07797980ef
#    creating: face-detection/.git/objects/05/
#  extracting: face-detection/.git/objects/05/17ed413532e2af6cab044b8af85a460d55d892
#    creating: face-detection/.git/objects/bc/
#  extracting: face-detection/.git/objects/bc/62d6a39905767b8eb0457760853dd4c9659c4e
#   inflating: face-detection/.git/packed-refs
#    creating: face-detection/.git/logs/
#    creating: face-detection/.git/logs/refs/
#    creating: face-detection/.git/logs/refs/remotes/
#    creating: face-detection/.git/logs/refs/remotes/origin/
#   inflating: face-detection/.git/logs/refs/remotes/origin/HEAD
#   inflating: face-detection/.git/logs/refs/remotes/origin/master
#    creating: face-detection/.git/logs/refs/heads/
#   inflating: face-detection/.git/logs/refs/heads/master
#   inflating: face-detection/.git/logs/HEAD
#  extracting: face-detection/.git/HEAD
#   inflating: face-detection/.git/config
#  extracting: face-detection/.git/COMMIT_EDITMSG
#   inflating: face-detection/.git/index
#   inflating: face-detection/.gitignore
#   inflating: face-detection/LICENSE
#   inflating: face-detection/README.md
#   inflating: face-detection/after_convert.png
#   inflating: face-detection/before_convert.png
#   inflating: face-detection/get_data.py
#   inflating: face-detection/graph.py
#   inflating: face-detection/lenet_architecture.png
#   inflating: face-detection/prepare_data.ipynb
#   inflating: face-detection/scores.py
#   inflating: face-detection/Face_Detection.ipynb
#    creating: face-detection/.ipynb_checkpoints/
#   inflating: face-detection/.ipynb_checkpoints/Face_Detection-checkpoint.ipynb
#    creating: face-detection/data/
#    creating: face-detection/data/convertedPics/
#   inflating: face-detection/data/convertedPics/3.png
#   inflating: face-detection/data/convertedPics/27.png
#   inflating: face-detection/data/convertedPics/34.png
#   inflating: face-detection/data/convertedPics/40.png
#   inflating: face-detection/data/convertedPics/45.png
#   inflating: face-detection/data/convertedPics/49.png
#   inflating: face-detection/data/convertedPics/55.png
#   inflating: face-detection/data/convertedPics/58.png
#   inflating: face-detection/data/convertedPics/61.png
#   inflating: face-detection/data/convertedPics/69.png
#   inflating: face-detection/data/convertedPics/72.png
#   inflating: face-detection/data/convertedPics/82.png
#   inflating: face-detection/data/convertedPics/105.png
#   inflating: face-detection/data/convertedPics/137.png
#   inflating: face-detection/data/convertedPics/140.png
#   inflating: face-detection/data/convertedPics/141.png
#   inflating: face-detection/data/convertedPics/159.png
#   inflating: face-detection/data/convertedPics/185.png
#   inflating: face-detection/data/convertedPics/190.png
#   inflating: face-detection/data/convertedPics/197.png
#   inflating: face-detection/data/convertedPics/203.png
#   inflating: face-detection/data/convertedPics/215.png
#   inflating: face-detection/data/convertedPics/217.png
#   inflating: face-detection/data/convertedPics/219.png
#   inflating: face-detection/data/convertedPics/222.png
#   inflating: face-detection/data/convertedPics/223.png
#   inflating: face-detection/data/convertedPics/225.png
#   inflating: face-detection/data/convertedPics/227.png
#   inflating: face-detection/data/convertedPics/229.png
#   inflating: face-detection/data/convertedPics/230.png
#   inflating: face-detection/data/convertedPics/254.png
#   inflating: face-detection/data/convertedPics/256.png
#   inflating: face-detection/data/convertedPics/265.png
#   inflating: face-detection/data/convertedPics/272.png
#   inflating: face-detection/data/convertedPics/284.png
#   inflating: face-detection/data/convertedPics/288.png
#   inflating: face-detection/data/convertedPics/306.png
#   inflating: face-detection/data/convertedPics/345.png
#   inflating: face-detection/data/convertedPics/364.png
#   inflating: face-detection/data/convertedPics/372.png
#   inflating: face-detection/data/convertedPics/375.png
#   inflating: face-detection/data/convertedPics/399.png
#   inflating: face-detection/data/convertedPics/408.png
#   inflating: face-detection/data/convertedPics/437.png
#   inflating: face-detection/data/convertedPics/446.png
#   inflating: face-detection/data/convertedPics/447.png
#   inflating: face-detection/data/convertedPics/453.png
#   inflating: face-detection/data/convertedPics/455.png
#   inflating: face-detection/data/convertedPics/494.png
#   inflating: face-detection/data/convertedPics/504.png
#   inflating: face-detection/data/convertedPics/505.png
#   inflating: face-detection/data/convertedPics/514.png
#   inflating: face-detection/data/convertedPics/515.png
#   inflating: face-detection/data/convertedPics/517.png
#   inflating: face-detection/data/convertedPics/523.png
#   inflating: face-detection/data/convertedPics/525.png
#   inflating: face-detection/data/convertedPics/527.png
#   inflating: face-detection/data/convertedPics/535.png
#   inflating: face-detection/data/convertedPics/553.png
#   inflating: face-detection/data/convertedPics/562.png
#   inflating: face-detection/data/convertedPics/573.png
#   inflating: face-detection/data/convertedPics/580.png
#   inflating: face-detection/data/convertedPics/585.png
#   inflating: face-detection/data/convertedPics/598.png
#   inflating: face-detection/data/convertedPics/601.png
#   inflating: face-detection/data/convertedPics/616.png
#   inflating: face-detection/data/convertedPics/622.png
#   inflating: face-detection/data/convertedPics/624.png
#   inflating: face-detection/data/convertedPics/646.png
#   inflating: face-detection/data/convertedPics/657.png
#   inflating: face-detection/data/convertedPics/665.png
#   inflating: face-detection/data/convertedPics/670.png
#   inflating: face-detection/data/convertedPics/682.png
#  extracting: face-detection/data/convertedPics/683.png
#   inflating: face-detection/data/convertedPics/690.png
#   inflating: face-detection/data/convertedPics/693.png
#   inflating: face-detection/data/convertedPics/709.png
#   inflating: face-detection/data/convertedPics/715.png
#   inflating: face-detection/data/convertedPics/716.png
#   inflating: face-detection/data/convertedPics/719.png
#   inflating: face-detection/data/convertedPics/734.png
#   inflating: face-detection/data/convertedPics/748.png
#   inflating: face-detection/data/convertedPics/749.png
#   inflating: face-detection/data/convertedPics/758.png
#   inflating: face-detection/data/convertedPics/793.png
#   inflating: face-detection/data/convertedPics/802.png
#   inflating: face-detection/data/convertedPics/803.png
#   inflating: face-detection/data/convertedPics/827.png
#   inflating: face-detection/data/convertedPics/830.png
#   inflating: face-detection/data/convertedPics/837.png
#   inflating: face-detection/data/convertedPics/844.png
#   inflating: face-detection/data/convertedPics/852.png
#   inflating: face-detection/data/convertedPics/868.png
#   inflating: face-detection/data/convertedPics/918.png
#   inflating: face-detection/data/convertedPics/937.png
#   inflating: face-detection/data/convertedPics/944.png
#   inflating: face-detection/data/convertedPics/962.png
#   inflating: face-detection/data/convertedPics/964.png
#   inflating: face-detection/data/convertedPics/966.png
#   inflating: face-detection/data/convertedPics/968.png
#   inflating: face-detection/data/convertedPics/986.png
#   inflating: face-detection/data/convertedPics/989.png
#   inflating: face-detection/data/convertedPics/991.png
#   inflating: face-detection/data/convertedPics/995.png
#   inflating: face-detection/data/convertedPics/997.png
#  extracting: face-detection/data/convertedPics/999.png
#   inflating: face-detection/data/convertedPics/1005.png
#   inflating: face-detection/data/convertedPics/1019.png
#   inflating: face-detection/data/convertedPics/1036.png
#   inflating: face-detection/data/convertedPics/1037.png
#   inflating: face-detection/data/convertedPics/1042.png
#   inflating: face-detection/data/convertedPics/1051.png
#   inflating: face-detection/data/convertedPics/1056.png
#   inflating: face-detection/data/convertedPics/1063.png
#   inflating: face-detection/data/convertedPics/1064.png
#   inflating: face-detection/data/convertedPics/1065.png
#   inflating: face-detection/data/convertedPics/1066.png
#   inflating: face-detection/data/convertedPics/1074.png
#   inflating: face-detection/data/convertedPics/1082.png
#   inflating: face-detection/data/convertedPics/1087.png
#   inflating: face-detection/data/convertedPics/1092.png
#   inflating: face-detection/data/convertedPics/1124.png
#   inflating: face-detection/data/convertedPics/1125.png
#   inflating: face-detection/data/convertedPics/1135.png
#   inflating: face-detection/data/convertedPics/1143.png
#   inflating: face-detection/data/convertedPics/1146.png
#   inflating: face-detection/data/convertedPics/1164.png
#   inflating: face-detection/data/convertedPics/1180.png
#   inflating: face-detection/data/convertedPics/1181.png
#   inflating: face-detection/data/convertedPics/1219.png
#   inflating: face-detection/data/convertedPics/1223.png
#   inflating: face-detection/data/convertedPics/1226.png
#   inflating: face-detection/data/convertedPics/1229.png
#   inflating: face-detection/data/convertedPics/1270.png
#   inflating: face-detection/data/convertedPics/1281.png
#   inflating: face-detection/data/convertedPics/1283.png
#   inflating: face-detection/data/convertedPics/1287.png
#   inflating: face-detection/data/convertedPics/1293.png
#   inflating: face-detection/data/convertedPics/1299.png
#   inflating: face-detection/data/convertedPics/1310.png
#   inflating: face-detection/data/convertedPics/1320.png
#   inflating: face-detection/data/convertedPics/1324.png
#   inflating: face-detection/data/convertedPics/1339.png
#   inflating: face-detection/data/convertedPics/1358.png
#   inflating: face-detection/data/convertedPics/1370.png
#   inflating: face-detection/data/convertedPics/1373.png
#   inflating: face-detection/data/convertedPics/1383.png
#   inflating: face-detection/data/convertedPics/1394.png
#   inflating: face-detection/data/convertedPics/1395.png
#  extracting: face-detection/data/convertedPics/1404.png
#   inflating: face-detection/data/convertedPics/1409.png
#   inflating: face-detection/data/convertedPics/1422.png
#   inflating: face-detection/data/convertedPics/1423.png
#   inflating: face-detection/data/convertedPics/1437.png
#   inflating: face-detection/data/convertedPics/1440.png
#   inflating: face-detection/data/convertedPics/1441.png
#   inflating: face-detection/data/convertedPics/1447.png
#   inflating: face-detection/data/convertedPics/1450.png
#   inflating: face-detection/data/convertedPics/1451.png
#   inflating: face-detection/data/convertedPics/1452.png
#   inflating: face-detection/data/convertedPics/1455.png
#   inflating: face-detection/data/convertedPics/1460.png
#   inflating: face-detection/data/convertedPics/1470.png
#   inflating: face-detection/data/convertedPics/1476.png
#   inflating: face-detection/data/convertedPics/1479.png
#   inflating: face-detection/data/convertedPics/1481.png
#   inflating: face-detection/data/convertedPics/1486.png
#   inflating: face-detection/data/convertedPics/1494.png
#   inflating: face-detection/data/convertedPics/1496.png
#   inflating: face-detection/data/convertedPics/1497.png
#   inflating: face-detection/data/convertedPics/1506.png
#   inflating: face-detection/data/convertedPics/1543.png
#   inflating: face-detection/data/convertedPics/1548.png
#   inflating: face-detection/data/convertedPics/1552.png
#   inflating: face-detection/data/convertedPics/1563.png
#   inflating: face-detection/data/convertedPics/1577.png
#   inflating: face-detection/data/convertedPics/1579.png
#   inflating: face-detection/data/convertedPics/1583.png
#   inflating: face-detection/data/convertedPics/1593.png
#   inflating: face-detection/data/convertedPics/1595.png
#   inflating: face-detection/data/convertedPics/1598.png
#   inflating: face-detection/data/convertedPics/1624.png
#   inflating: face-detection/data/convertedPics/1628.png
#   inflating: face-detection/data/convertedPics/1629.png
#   inflating: face-detection/data/convertedPics/1630.png
#   inflating: face-detection/data/convertedPics/1637.png
#   inflating: face-detection/data/convertedPics/1641.png
#   inflating: face-detection/data/convertedPics/1643.png
#   inflating: face-detection/data/convertedPics/1649.png
#   inflating: face-detection/data/convertedPics/1650.png
#   inflating: face-detection/data/convertedPics/1656.png
#   inflating: face-detection/data/convertedPics/1657.png
#   inflating: face-detection/data/convertedPics/1661.png
#   inflating: face-detection/data/convertedPics/1662.png
#   inflating: face-detection/data/convertedPics/1669.png
#   inflating: face-detection/data/convertedPics/1672.png
#   inflating: face-detection/data/convertedPics/1678.png
#   inflating: face-detection/data/convertedPics/1679.png
#   inflating: face-detection/data/convertedPics/1692.png
#   inflating: face-detection/data/convertedPics/1715.png
#   inflating: face-detection/data/convertedPics/1717.png
#   inflating: face-detection/data/convertedPics/1722.png
#   inflating: face-detection/data/convertedPics/1723.png
#   inflating: face-detection/data/convertedPics/1728.png
#   inflating: face-detection/data/convertedPics/1733.png
#   inflating: face-detection/data/convertedPics/1735.png
#   inflating: face-detection/data/convertedPics/1747.png
#   inflating: face-detection/data/convertedPics/1763.png
#   inflating: face-detection/data/convertedPics/1765.png
#   inflating: face-detection/data/convertedPics/1770.png
#   inflating: face-detection/data/convertedPics/1791.png
#   inflating: face-detection/data/convertedPics/1815.png
#   inflating: face-detection/data/convertedPics/1822.png
#   inflating: face-detection/data/convertedPics/1830.png
#   inflating: face-detection/data/convertedPics/1832.png
#   inflating: face-detection/data/convertedPics/1834.png
#   inflating: face-detection/data/convertedPics/1859.png
#   inflating: face-detection/data/convertedPics/1870.png
#   inflating: face-detection/data/convertedPics/1872.png
#   inflating: face-detection/data/convertedPics/1880.png
#   inflating: face-detection/data/convertedPics/1881.png
#  extracting: face-detection/data/convertedPics/1894.png
#   inflating: face-detection/data/convertedPics/1907.png
#   inflating: face-detection/data/convertedPics/1912.png
#   inflating: face-detection/data/convertedPics/1915.png
#   inflating: face-detection/data/convertedPics/1928.png
#   inflating: face-detection/data/convertedPics/1936.png
#   inflating: face-detection/data/convertedPics/1947.png
#   inflating: face-detection/data/convertedPics/1953.png
#   inflating: face-detection/data/convertedPics/1954.png
#   inflating: face-detection/data/convertedPics/1956.png
#   inflating: face-detection/data/convertedPics/1964.png
#   inflating: face-detection/data/convertedPics/1978.png
#   inflating: face-detection/data/convertedPics/1987.png
#   inflating: face-detection/data/convertedPics/1994.png
#   inflating: face-detection/data/convertedPics/1995.png
#   inflating: face-detection/data/convertedPics/1998.png
#   inflating: face-detection/data/convertedPics/1999.png
#   inflating: face-detection/data/convertedPics/2017.png
#   inflating: face-detection/data/convertedPics/2024.png
#   inflating: face-detection/data/convertedPics/2025.png
#   inflating: face-detection/data/convertedPics/2026.png
#   inflating: face-detection/data/convertedPics/2060.png
#   inflating: face-detection/data/convertedPics/2061.png
#  extracting: face-detection/data/convertedPics/2070.png
#   inflating: face-detection/data/convertedPics/2072.png
#   inflating: face-detection/data/convertedPics/2074.png
#   inflating: face-detection/data/convertedPics/2087.png
#   inflating: face-detection/data/convertedPics/2096.png
#   inflating: face-detection/data/convertedPics/2099.png
#   inflating: face-detection/data/convertedPics/2104.png
#   inflating: face-detection/data/convertedPics/2111.png
#   inflating: face-detection/data/convertedPics/2120.png
#   inflating: face-detection/data/convertedPics/2126.png
#   inflating: face-detection/data/convertedPics/2127.png
#   inflating: face-detection/data/convertedPics/2137.png
#   inflating: face-detection/data/convertedPics/2138.png
#   inflating: face-detection/data/convertedPics/2140.png
#   inflating: face-detection/data/convertedPics/2180.png
#   inflating: face-detection/data/convertedPics/2185.png
#   inflating: face-detection/data/convertedPics/2192.png
#   inflating: face-detection/data/convertedPics/2196.png
#   inflating: face-detection/data/convertedPics/2197.png
#   inflating: face-detection/data/convertedPics/2204.png
#   inflating: face-detection/data/convertedPics/2205.png
#   inflating: face-detection/data/convertedPics/2220.png
#   inflating: face-detection/data/convertedPics/2222.png
#   inflating: face-detection/data/convertedPics/2225.png
#   inflating: face-detection/data/convertedPics/2226.png
#   inflating: face-detection/data/convertedPics/2234.png
#   inflating: face-detection/data/convertedPics/2235.png
#   inflating: face-detection/data/convertedPics/2237.png
#   inflating: face-detection/data/convertedPics/2247.png
#   inflating: face-detection/data/convertedPics/2248.png
#   inflating: face-detection/data/convertedPics/2263.png
#   inflating: face-detection/data/convertedPics/2269.png
#   inflating: face-detection/data/convertedPics/2271.png
#   inflating: face-detection/data/convertedPics/2283.png
#   inflating: face-detection/data/convertedPics/2309.png
#   inflating: face-detection/data/convertedPics/2311.png
#   inflating: face-detection/data/convertedPics/2326.png
#   inflating: face-detection/data/convertedPics/2328.png
#   inflating: face-detection/data/convertedPics/2334.png
#   inflating: face-detection/data/convertedPics/2337.png
#   inflating: face-detection/data/convertedPics/2360.png
#   inflating: face-detection/data/convertedPics/2361.png
#   inflating: face-detection/data/convertedPics/2368.png
#   inflating: face-detection/data/convertedPics/2371.png
#   inflating: face-detection/data/convertedPics/2372.png
#   inflating: face-detection/data/convertedPics/2381.png
#   inflating: face-detection/data/convertedPics/2396.png
#   inflating: face-detection/data/convertedPics/2397.png
#   inflating: face-detection/data/convertedPics/2400.png
#   inflating: face-detection/data/convertedPics/2403.png
#   inflating: face-detection/data/convertedPics/2406.png
#   inflating: face-detection/data/convertedPics/2414.png
#   inflating: face-detection/data/convertedPics/2415.png
#   inflating: face-detection/data/convertedPics/2442.png
#  extracting: face-detection/data/convertedPics/2444.png
#   inflating: face-detection/data/convertedPics/2445.png
#   inflating: face-detection/data/convertedPics/2454.png
#   inflating: face-detection/data/convertedPics/2455.png
#   inflating: face-detection/data/convertedPics/2459.png
#   inflating: face-detection/data/convertedPics/2460.png
#   inflating: face-detection/data/convertedPics/2461.png
#   inflating: face-detection/data/convertedPics/2463.png
#   inflating: face-detection/data/convertedPics/2473.png
#   inflating: face-detection/data/convertedPics/2479.png
#   inflating: face-detection/data/convertedPics/2481.png
#   inflating: face-detection/data/convertedPics/2494.png
#   inflating: face-detection/data/convertedPics/2495.png
#   inflating: face-detection/data/convertedPics/2504.png
#   inflating: face-detection/data/convertedPics/2507.png
#   inflating: face-detection/data/convertedPics/2513.png
#   inflating: face-detection/data/convertedPics/2521.png
#   inflating: face-detection/data/convertedPics/2524.png
#   inflating: face-detection/data/convertedPics/2532.png
#   inflating: face-detection/data/convertedPics/2533.png
#   inflating: face-detection/data/convertedPics/2544.png
#  extracting: face-detection/data/convertedPics/2547.png
#   inflating: face-detection/data/convertedPics/2548.png
#   inflating: face-detection/data/convertedPics/2556.png
#   inflating: face-detection/data/convertedPics/2570.png
#   inflating: face-detection/data/convertedPics/2578.png
#   inflating: face-detection/data/convertedPics/2581.png
#   inflating: face-detection/data/convertedPics/2617.png
#   inflating: face-detection/data/convertedPics/2621.png
#   inflating: face-detection/data/convertedPics/2634.png
#   inflating: face-detection/data/convertedPics/2635.png
#   inflating: face-detection/data/convertedPics/2639.png
#   inflating: face-detection/data/convertedPics/2650.png
#   inflating: face-detection/data/convertedPics/2654.png
#   inflating: face-detection/data/convertedPics/2655.png
#   inflating: face-detection/data/convertedPics/2662.png
#   inflating: face-detection/data/convertedPics/2668.png
#   inflating: face-detection/data/convertedPics/2683.png
#   inflating: face-detection/data/convertedPics/2690.png
#   inflating: face-detection/data/convertedPics/2700.png
#   inflating: face-detection/data/convertedPics/2719.png
#   inflating: face-detection/data/convertedPics/2723.png
#   inflating: face-detection/data/convertedPics/2729.png
#   inflating: face-detection/data/convertedPics/2730.png
#   inflating: face-detection/data/convertedPics/2740.png
#   inflating: face-detection/data/convertedPics/2741.png
#   inflating: face-detection/data/convertedPics/2744.png
#   inflating: face-detection/data/convertedPics/2749.png
#   inflating: face-detection/data/convertedPics/2750.png
#   inflating: face-detection/data/convertedPics/2777.png
#   inflating: face-detection/data/convertedPics/2785.png
#   inflating: face-detection/data/convertedPics/2787.png
#   inflating: face-detection/data/convertedPics/2795.png
#   inflating: face-detection/data/convertedPics/2801.png
#   inflating: face-detection/data/convertedPics/2803.png
#   inflating: face-detection/data/convertedPics/2817.png
#   inflating: face-detection/data/convertedPics/2820.png
#   inflating: face-detection/data/convertedPics/2828.png
#   inflating: face-detection/data/convertedPics/2829.png
#   inflating: face-detection/data/convertedPics/2842.png
#   inflating: face-detection/data/convertedPics/0.png
#   inflating: face-detection/data/convertedPics/2.png
#   inflating: face-detection/data/convertedPics/8.png
#   inflating: face-detection/data/convertedPics/9.png
#   inflating: face-detection/data/convertedPics/10.png
#   inflating: face-detection/data/convertedPics/13.png
#   inflating: face-detection/data/convertedPics/14.png
#   inflating: face-detection/data/convertedPics/15.png
#   inflating: face-detection/data/convertedPics/16.png
#   inflating: face-detection/data/convertedPics/21.png
#   inflating: face-detection/data/convertedPics/22.png
#   inflating: face-detection/data/convertedPics/23.png
#   inflating: face-detection/data/convertedPics/24.png
#   inflating: face-detection/data/convertedPics/25.png
#   inflating: face-detection/data/convertedPics/26.png
#   inflating: face-detection/data/convertedPics/28.png
#   inflating: face-detection/data/convertedPics/29.png
#   inflating: face-detection/data/convertedPics/36.png
#   inflating: face-detection/data/convertedPics/37.png
#   inflating: face-detection/data/convertedPics/39.png
#   inflating: face-detection/data/convertedPics/42.png
#   inflating: face-detection/data/convertedPics/43.png
#   inflating: face-detection/data/convertedPics/46.png
#   inflating: face-detection/data/convertedPics/47.png
#   inflating: face-detection/data/convertedPics/50.png
#   inflating: face-detection/data/convertedPics/51.png
#   inflating: face-detection/data/convertedPics/53.png
#   inflating: face-detection/data/convertedPics/54.png
#   inflating: face-detection/data/convertedPics/56.png
#   inflating: face-detection/data/convertedPics/60.png
#   inflating: face-detection/data/convertedPics/73.png
#   inflating: face-detection/data/convertedPics/75.png
#   inflating: face-detection/data/convertedPics/78.png
#   inflating: face-detection/data/convertedPics/80.png
#   inflating: face-detection/data/convertedPics/81.png
#   inflating: face-detection/data/convertedPics/84.png
#   inflating: face-detection/data/convertedPics/85.png
#   inflating: face-detection/data/convertedPics/87.png
#   inflating: face-detection/data/convertedPics/90.png
#   inflating: face-detection/data/convertedPics/91.png
#   inflating: face-detection/data/convertedPics/95.png
#   inflating: face-detection/data/convertedPics/97.png
#   inflating: face-detection/data/convertedPics/98.png
#   inflating: face-detection/data/convertedPics/100.png
#   inflating: face-detection/data/convertedPics/101.png
#   inflating: face-detection/data/convertedPics/102.png
#   inflating: face-detection/data/convertedPics/103.png
#   inflating: face-detection/data/convertedPics/108.png
#   inflating: face-detection/data/convertedPics/111.png
#   inflating: face-detection/data/convertedPics/113.png
#   inflating: face-detection/data/convertedPics/114.png
#   inflating: face-detection/data/convertedPics/115.png
#   inflating: face-detection/data/convertedPics/124.png
#   inflating: face-detection/data/convertedPics/125.png
#   inflating: face-detection/data/convertedPics/128.png
#   inflating: face-detection/data/convertedPics/129.png
#   inflating: face-detection/data/convertedPics/132.png
#   inflating: face-detection/data/convertedPics/133.png
#   inflating: face-detection/data/convertedPics/134.png
#   inflating: face-detection/data/convertedPics/135.png
#   inflating: face-detection/data/convertedPics/138.png
#   inflating: face-detection/data/convertedPics/139.png
#   inflating: face-detection/data/convertedPics/142.png
#   inflating: face-detection/data/convertedPics/146.png
#   inflating: face-detection/data/convertedPics/147.png
#   inflating: face-detection/data/convertedPics/150.png
#   inflating: face-detection/data/convertedPics/152.png
#   inflating: face-detection/data/convertedPics/154.png
#   inflating: face-detection/data/convertedPics/155.png
#   inflating: face-detection/data/convertedPics/157.png
#   inflating: face-detection/data/convertedPics/158.png
#   inflating: face-detection/data/convertedPics/161.png
#   inflating: face-detection/data/convertedPics/164.png
#   inflating: face-detection/data/convertedPics/167.png
#   inflating: face-detection/data/convertedPics/170.png
#   inflating: face-detection/data/convertedPics/173.png
#   inflating: face-detection/data/convertedPics/176.png
#   inflating: face-detection/data/convertedPics/180.png
#   inflating: face-detection/data/convertedPics/181.png
#   inflating: face-detection/data/convertedPics/183.png
#   inflating: face-detection/data/convertedPics/184.png
#   inflating: face-detection/data/convertedPics/186.png
#   inflating: face-detection/data/convertedPics/187.png
#   inflating: face-detection/data/convertedPics/188.png
#   inflating: face-detection/data/convertedPics/191.png
#   inflating: face-detection/data/convertedPics/195.png
#   inflating: face-detection/data/convertedPics/201.png
#   inflating: face-detection/data/convertedPics/202.png
#   inflating: face-detection/data/convertedPics/205.png
#   inflating: face-detection/data/convertedPics/206.png
#   inflating: face-detection/data/convertedPics/207.png
#   inflating: face-detection/data/convertedPics/208.png
#   inflating: face-detection/data/convertedPics/209.png
#   inflating: face-detection/data/convertedPics/210.png
#   inflating: face-detection/data/convertedPics/211.png
#   inflating: face-detection/data/convertedPics/216.png
#   inflating: face-detection/data/convertedPics/220.png
#   inflating: face-detection/data/convertedPics/221.png
#   inflating: face-detection/data/convertedPics/224.png
#   inflating: face-detection/data/convertedPics/228.png
#   inflating: face-detection/data/convertedPics/232.png
#   inflating: face-detection/data/convertedPics/234.png
#   inflating: face-detection/data/convertedPics/235.png
#   inflating: face-detection/data/convertedPics/237.png
#   inflating: face-detection/data/convertedPics/239.png
#   inflating: face-detection/data/convertedPics/240.png
#   inflating: face-detection/data/convertedPics/242.png
#   inflating: face-detection/data/convertedPics/246.png
#   inflating: face-detection/data/convertedPics/252.png
#   inflating: face-detection/data/convertedPics/253.png
#   inflating: face-detection/data/convertedPics/255.png
#   inflating: face-detection/data/convertedPics/257.png
#   inflating: face-detection/data/convertedPics/258.png
#   inflating: face-detection/data/convertedPics/259.png
#   inflating: face-detection/data/convertedPics/260.png
#   inflating: face-detection/data/convertedPics/261.png
#   inflating: face-detection/data/convertedPics/262.png
#   inflating: face-detection/data/convertedPics/266.png
#   inflating: face-detection/data/convertedPics/270.png
#   inflating: face-detection/data/convertedPics/275.png
#   inflating: face-detection/data/convertedPics/277.png
#   inflating: face-detection/data/convertedPics/278.png
#   inflating: face-detection/data/convertedPics/280.png
#   inflating: face-detection/data/convertedPics/281.png
#   inflating: face-detection/data/convertedPics/282.png
#   inflating: face-detection/data/convertedPics/283.png
#   inflating: face-detection/data/convertedPics/285.png
#   inflating: face-detection/data/convertedPics/289.png
#   inflating: face-detection/data/convertedPics/291.png
#   inflating: face-detection/data/convertedPics/294.png
#   inflating: face-detection/data/convertedPics/296.png
#   inflating: face-detection/data/convertedPics/298.png
#   inflating: face-detection/data/convertedPics/300.png
#   inflating: face-detection/data/convertedPics/308.png
#   inflating: face-detection/data/convertedPics/309.png
#   inflating: face-detection/data/convertedPics/314.png
#   inflating: face-detection/data/convertedPics/316.png
#   inflating: face-detection/data/convertedPics/317.png
#   inflating: face-detection/data/convertedPics/318.png
#   inflating: face-detection/data/convertedPics/319.png
#   inflating: face-detection/data/convertedPics/321.png
#   inflating: face-detection/data/convertedPics/323.png
#   inflating: face-detection/data/convertedPics/324.png
#   inflating: face-detection/data/convertedPics/325.png
#   inflating: face-detection/data/convertedPics/326.png
#   inflating: face-detection/data/convertedPics/327.png
#   inflating: face-detection/data/convertedPics/328.png
#   inflating: face-detection/data/convertedPics/330.png
#   inflating: face-detection/data/convertedPics/335.png
#   inflating: face-detection/data/convertedPics/339.png
#   inflating: face-detection/data/convertedPics/340.png
#   inflating: face-detection/data/convertedPics/341.png
#   inflating: face-detection/data/convertedPics/342.png
#   inflating: face-detection/data/convertedPics/346.png
#   inflating: face-detection/data/convertedPics/348.png
#   inflating: face-detection/data/convertedPics/350.png
#   inflating: face-detection/data/convertedPics/354.png
#   inflating: face-detection/data/convertedPics/355.png
#   inflating: face-detection/data/convertedPics/357.png
#   inflating: face-detection/data/convertedPics/358.png
#   inflating: face-detection/data/convertedPics/359.png
#   inflating: face-detection/data/convertedPics/361.png
#   inflating: face-detection/data/convertedPics/362.png
#   inflating: face-detection/data/convertedPics/367.png
#   inflating: face-detection/data/convertedPics/368.png
#   inflating: face-detection/data/convertedPics/369.png
#   inflating: face-detection/data/convertedPics/371.png
#   inflating: face-detection/data/convertedPics/376.png
#   inflating: face-detection/data/convertedPics/377.png
#   inflating: face-detection/data/convertedPics/379.png
#   inflating: face-detection/data/convertedPics/380.png
#   inflating: face-detection/data/convertedPics/383.png
#   inflating: face-detection/data/convertedPics/385.png
#   inflating: face-detection/data/convertedPics/391.png
#   inflating: face-detection/data/convertedPics/392.png
#   inflating: face-detection/data/convertedPics/394.png
#   inflating: face-detection/data/convertedPics/395.png
#   inflating: face-detection/data/convertedPics/397.png
#   inflating: face-detection/data/convertedPics/403.png
#   inflating: face-detection/data/convertedPics/405.png
#   inflating: face-detection/data/convertedPics/409.png
#   inflating: face-detection/data/convertedPics/411.png
#   inflating: face-detection/data/convertedPics/415.png
#   inflating: face-detection/data/convertedPics/416.png
#   inflating: face-detection/data/convertedPics/417.png
#   inflating: face-detection/data/convertedPics/418.png
#   inflating: face-detection/data/convertedPics/421.png
#   inflating: face-detection/data/convertedPics/423.png
#   inflating: face-detection/data/convertedPics/424.png
#   inflating: face-detection/data/convertedPics/427.png
#   inflating: face-detection/data/convertedPics/428.png
#   inflating: face-detection/data/convertedPics/431.png
#   inflating: face-detection/data/convertedPics/432.png
#   inflating: face-detection/data/convertedPics/433.png
#   inflating: face-detection/data/convertedPics/434.png
#   inflating: face-detection/data/convertedPics/435.png
#   inflating: face-detection/data/convertedPics/439.png
#   inflating: face-detection/data/convertedPics/441.png
#   inflating: face-detection/data/convertedPics/443.png
#   inflating: face-detection/data/convertedPics/449.png
#   inflating: face-detection/data/convertedPics/450.png
#   inflating: face-detection/data/convertedPics/456.png
#   inflating: face-detection/data/convertedPics/458.png
#   inflating: face-detection/data/convertedPics/459.png
#   inflating: face-detection/data/convertedPics/462.png
#   inflating: face-detection/data/convertedPics/463.png
#   inflating: face-detection/data/convertedPics/464.png
#   inflating: face-detection/data/convertedPics/465.png
#   inflating: face-detection/data/convertedPics/467.png
#   inflating: face-detection/data/convertedPics/471.png
#   inflating: face-detection/data/convertedPics/473.png
#   inflating: face-detection/data/convertedPics/479.png
#   inflating: face-detection/data/convertedPics/481.png
#   inflating: face-detection/data/convertedPics/483.png
#   inflating: face-detection/data/convertedPics/488.png
#   inflating: face-detection/data/convertedPics/489.png
#   inflating: face-detection/data/convertedPics/490.png
#   inflating: face-detection/data/convertedPics/491.png
#   inflating: face-detection/data/convertedPics/497.png
#   inflating: face-detection/data/convertedPics/500.png
#   inflating: face-detection/data/convertedPics/501.png
#   inflating: face-detection/data/convertedPics/502.png
#   inflating: face-detection/data/convertedPics/513.png
#   inflating: face-detection/data/convertedPics/516.png
#   inflating: face-detection/data/convertedPics/518.png
#   inflating: face-detection/data/convertedPics/524.png
#   inflating: face-detection/data/convertedPics/530.png
#   inflating: face-detection/data/convertedPics/531.png
#   inflating: face-detection/data/convertedPics/532.png
#   inflating: face-detection/data/convertedPics/536.png
#   inflating: face-detection/data/convertedPics/539.png
#   inflating: face-detection/data/convertedPics/540.png
#   inflating: face-detection/data/convertedPics/544.png
#   inflating: face-detection/data/convertedPics/545.png
#   inflating: face-detection/data/convertedPics/546.png
#   inflating: face-detection/data/convertedPics/548.png
#   inflating: face-detection/data/convertedPics/551.png
#   inflating: face-detection/data/convertedPics/552.png
#   inflating: face-detection/data/convertedPics/554.png
#   inflating: face-detection/data/convertedPics/556.png
#   inflating: face-detection/data/convertedPics/557.png
#   inflating: face-detection/data/convertedPics/559.png
#   inflating: face-detection/data/convertedPics/560.png
#   inflating: face-detection/data/convertedPics/561.png
#   inflating: face-detection/data/convertedPics/564.png
#   inflating: face-detection/data/convertedPics/568.png
#   inflating: face-detection/data/convertedPics/569.png
#   inflating: face-detection/data/convertedPics/571.png
#   inflating: face-detection/data/convertedPics/572.png
#   inflating: face-detection/data/convertedPics/574.png
#   inflating: face-detection/data/convertedPics/576.png
#   inflating: face-detection/data/convertedPics/577.png
#   inflating: face-detection/data/convertedPics/578.png
#   inflating: face-detection/data/convertedPics/584.png
#   inflating: face-detection/data/convertedPics/590.png
#   inflating: face-detection/data/convertedPics/591.png
#   inflating: face-detection/data/convertedPics/592.png
#   inflating: face-detection/data/convertedPics/593.png
#   inflating: face-detection/data/convertedPics/600.png
#   inflating: face-detection/data/convertedPics/603.png
#   inflating: face-detection/data/convertedPics/606.png
#   inflating: face-detection/data/convertedPics/619.png
#   inflating: face-detection/data/convertedPics/620.png
#   inflating: face-detection/data/convertedPics/623.png
#   inflating: face-detection/data/convertedPics/625.png
#   inflating: face-detection/data/convertedPics/627.png
#   inflating: face-detection/data/convertedPics/629.png
#   inflating: face-detection/data/convertedPics/631.png
#   inflating: face-detection/data/convertedPics/632.png
#   inflating: face-detection/data/convertedPics/633.png
#   inflating: face-detection/data/convertedPics/634.png
#   inflating: face-detection/data/convertedPics/635.png
#   inflating: face-detection/data/convertedPics/640.png
#   inflating: face-detection/data/convertedPics/641.png
#   inflating: face-detection/data/convertedPics/642.png
#   inflating: face-detection/data/convertedPics/643.png
#   inflating: face-detection/data/convertedPics/645.png
#   inflating: face-detection/data/convertedPics/647.png
#   inflating: face-detection/data/convertedPics/648.png
#   inflating: face-detection/data/convertedPics/649.png
#   inflating: face-detection/data/convertedPics/654.png
#   inflating: face-detection/data/convertedPics/655.png
#   inflating: face-detection/data/convertedPics/656.png
#   inflating: face-detection/data/convertedPics/659.png
#   inflating: face-detection/data/convertedPics/662.png
#   inflating: face-detection/data/convertedPics/664.png
#   inflating: face-detection/data/convertedPics/667.png
#   inflating: face-detection/data/convertedPics/669.png
#   inflating: face-detection/data/convertedPics/674.png
#   inflating: face-detection/data/convertedPics/677.png
#   inflating: face-detection/data/convertedPics/678.png
#   inflating: face-detection/data/convertedPics/679.png
#   inflating: face-detection/data/convertedPics/684.png
#   inflating: face-detection/data/convertedPics/685.png
#   inflating: face-detection/data/convertedPics/687.png
#   inflating: face-detection/data/convertedPics/688.png
#   inflating: face-detection/data/convertedPics/691.png
#   inflating: face-detection/data/convertedPics/692.png
#   inflating: face-detection/data/convertedPics/694.png
#   inflating: face-detection/data/convertedPics/696.png
#   inflating: face-detection/data/convertedPics/697.png
#   inflating: face-detection/data/convertedPics/699.png
#   inflating: face-detection/data/convertedPics/700.png
#   inflating: face-detection/data/convertedPics/705.png
#   inflating: face-detection/data/convertedPics/712.png
#   inflating: face-detection/data/convertedPics/713.png
#   inflating: face-detection/data/convertedPics/714.png
#   inflating: face-detection/data/convertedPics/720.png
#   inflating: face-detection/data/convertedPics/722.png
#   inflating: face-detection/data/convertedPics/723.png
#   inflating: face-detection/data/convertedPics/724.png
#   inflating: face-detection/data/convertedPics/729.png
#   inflating: face-detection/data/convertedPics/732.png
#   inflating: face-detection/data/convertedPics/733.png
#   inflating: face-detection/data/convertedPics/735.png
#   inflating: face-detection/data/convertedPics/737.png
#   inflating: face-detection/data/convertedPics/738.png
#   inflating: face-detection/data/convertedPics/739.png
#   inflating: face-detection/data/convertedPics/741.png
#   inflating: face-detection/data/convertedPics/744.png
#   inflating: face-detection/data/convertedPics/752.png
#   inflating: face-detection/data/convertedPics/756.png
#   inflating: face-detection/data/convertedPics/757.png
#   inflating: face-detection/data/convertedPics/759.png
#   inflating: face-detection/data/convertedPics/760.png
#   inflating: face-detection/data/convertedPics/764.png
#   inflating: face-detection/data/convertedPics/766.png
#   inflating: face-detection/data/convertedPics/768.png
#   inflating: face-detection/data/convertedPics/771.png
#   inflating: face-detection/data/convertedPics/773.png
#   inflating: face-detection/data/convertedPics/775.png
#   inflating: face-detection/data/convertedPics/784.png
#   inflating: face-detection/data/convertedPics/785.png
#   inflating: face-detection/data/convertedPics/790.png
#   inflating: face-detection/data/convertedPics/791.png
#   inflating: face-detection/data/convertedPics/792.png
#   inflating: face-detection/data/convertedPics/794.png
#   inflating: face-detection/data/convertedPics/795.png
#   inflating: face-detection/data/convertedPics/799.png
#   inflating: face-detection/data/convertedPics/800.png
#   inflating: face-detection/data/convertedPics/801.png
#   inflating: face-detection/data/convertedPics/804.png
#   inflating: face-detection/data/convertedPics/808.png
#   inflating: face-detection/data/convertedPics/809.png
#   inflating: face-detection/data/convertedPics/810.png
#   inflating: face-detection/data/convertedPics/812.png
#   inflating: face-detection/data/convertedPics/816.png
#   inflating: face-detection/data/convertedPics/818.png
#   inflating: face-detection/data/convertedPics/819.png
#   inflating: face-detection/data/convertedPics/820.png
#   inflating: face-detection/data/convertedPics/821.png
#   inflating: face-detection/data/convertedPics/822.png
#   inflating: face-detection/data/convertedPics/823.png
#   inflating: face-detection/data/convertedPics/826.png
#   inflating: face-detection/data/convertedPics/828.png
#   inflating: face-detection/data/convertedPics/831.png
#   inflating: face-detection/data/convertedPics/834.png
#   inflating: face-detection/data/convertedPics/835.png
#   inflating: face-detection/data/convertedPics/836.png
#   inflating: face-detection/data/convertedPics/839.png
#   inflating: face-detection/data/convertedPics/840.png
#   inflating: face-detection/data/convertedPics/841.png
#   inflating: face-detection/data/convertedPics/842.png
#   inflating: face-detection/data/convertedPics/843.png
#   inflating: face-detection/data/convertedPics/846.png
#   inflating: face-detection/data/convertedPics/847.png
#   inflating: face-detection/data/convertedPics/848.png
#   inflating: face-detection/data/convertedPics/858.png
#   inflating: face-detection/data/convertedPics/862.png
#   inflating: face-detection/data/convertedPics/864.png
#   inflating: face-detection/data/convertedPics/866.png
#   inflating: face-detection/data/convertedPics/867.png
#   inflating: face-detection/data/convertedPics/869.png
#   inflating: face-detection/data/convertedPics/871.png
#   inflating: face-detection/data/convertedPics/875.png
#   inflating: face-detection/data/convertedPics/879.png
#   inflating: face-detection/data/convertedPics/880.png
#   inflating: face-detection/data/convertedPics/881.png
#   inflating: face-detection/data/convertedPics/882.png
#   inflating: face-detection/data/convertedPics/883.png
#   inflating: face-detection/data/convertedPics/884.png
#   inflating: face-detection/data/convertedPics/885.png
#   inflating: face-detection/data/convertedPics/886.png
#   inflating: face-detection/data/convertedPics/887.png
#   inflating: face-detection/data/convertedPics/888.png
#   inflating: face-detection/data/convertedPics/889.png
#   inflating: face-detection/data/convertedPics/890.png
#   inflating: face-detection/data/convertedPics/891.png
#   inflating: face-detection/data/convertedPics/892.png
#   inflating: face-detection/data/convertedPics/894.png
#   inflating: face-detection/data/convertedPics/895.png
#   inflating: face-detection/data/convertedPics/897.png
#   inflating: face-detection/data/convertedPics/899.png
#   inflating: face-detection/data/convertedPics/902.png
#   inflating: face-detection/data/convertedPics/907.png
#   inflating: face-detection/data/convertedPics/909.png
#   inflating: face-detection/data/convertedPics/911.png
#   inflating: face-detection/data/convertedPics/912.png
#   inflating: face-detection/data/convertedPics/913.png
#   inflating: face-detection/data/convertedPics/914.png
#   inflating: face-detection/data/convertedPics/915.png
#   inflating: face-detection/data/convertedPics/916.png
#   inflating: face-detection/data/convertedPics/917.png
#   inflating: face-detection/data/convertedPics/919.png
#   inflating: face-detection/data/convertedPics/926.png
#   inflating: face-detection/data/convertedPics/928.png
#   inflating: face-detection/data/convertedPics/931.png
#   inflating: face-detection/data/convertedPics/932.png
#   inflating: face-detection/data/convertedPics/934.png
#   inflating: face-detection/data/convertedPics/935.png
#   inflating: face-detection/data/convertedPics/940.png
# ...
#   inflating: face-detection/data/convertedPics/2167.png
#   inflating: face-detection/data/convertedPics/2168.png
#   inflating: face-detection/data/convertedPics/2169.png
#   inflating: face-detection/data/convertedPics/2170.png
#   inflating: face-detection/data/convertedPics/2171.png
#   inflating: face-detection/data/convertedPics/2175.png
#   inflating: face-detection/data/convertedPics/2176.png
#   inflating: face-detection/data/convertedPics/2178.png
#   inflating: face-detection/data/convertedPics/2179.png
#   inflating: face-detection/data/convertedPics/2187.png
#   inflating: face-detection/data/convertedPics/2188.png
#   inflating: face-detection/data/convertedPics/2189.png
#   inflating: face-detection/data/convertedPics/2193.png
#   inflating: face-detection/data/convertedPics/2194.png
#   inflating: face-detection/data/convertedPics/2195.png
#   inflating: face-detection/data/convertedPics/2201.png
#   inflating: face-detection/data/convertedPics/2203.png
#   inflating: face-detection/data/convertedPics/2210.png
#   inflating: face-detection/data/convertedPics/2216.png
#   inflating: face-detection/data/convertedPics/2217.png
#   inflating: face-detection/data/convertedPics/2218.png
#   inflating: face-detection/data/convertedPics/2223.png
#   inflating: face-detection/data/convertedPics/2227.png
#   inflating: face-detection/data/convertedPics/2233.png
#   inflating: face-detection/data/convertedPics/2238.png
#   inflating: face-detection/data/convertedPics/2240.png
#   inflating: face-detection/data/convertedPics/2241.png
#   inflating: face-detection/data/convertedPics/2243.png
#   inflating: face-detection/data/convertedPics/2246.png
#   inflating: face-detection/data/convertedPics/2254.png
#   inflating: face-detection/data/convertedPics/2260.png
#   inflating: face-detection/data/convertedPics/2261.png
#   inflating: face-detection/data/convertedPics/2262.png
#   inflating: face-detection/data/convertedPics/2265.png
#   inflating: face-detection/data/convertedPics/2266.png
#   inflating: face-detection/data/convertedPics/2267.png
#   inflating: face-detection/data/convertedPics/2272.png
#   inflating: face-detection/data/convertedPics/2273.png
#   inflating: face-detection/data/convertedPics/2274.png
#   inflating: face-detection/data/convertedPics/2276.png
#   inflating: face-detection/data/convertedPics/2279.png
#   inflating: face-detection/data/convertedPics/2280.png
#   inflating: face-detection/data/convertedPics/2281.png
#   inflating: face-detection/data/convertedPics/2282.png
#   inflating: face-detection/data/convertedPics/2284.png
#   inflating: face-detection/data/convertedPics/2285.png
#   inflating: face-detection/data/convertedPics/2286.png
#   inflating: face-detection/data/convertedPics/2288.png
#   inflating: face-detection/data/convertedPics/2289.png
#   inflating: face-detection/data/convertedPics/2290.png
#   inflating: face-detection/data/convertedPics/2292.png
#   inflating: face-detection/data/convertedPics/2296.png
#   inflating: face-detection/data/convertedPics/2297.png
#   inflating: face-detection/data/convertedPics/2303.png
#   inflating: face-detection/data/convertedPics/2304.png
#   inflating: face-detection/data/convertedPics/2306.png
#   inflating: face-detection/data/convertedPics/2310.png
#   inflating: face-detection/data/convertedPics/2312.png
#   inflating: face-detection/data/convertedPics/2315.png
#   inflating: face-detection/data/convertedPics/2318.png
#   inflating: face-detection/data/convertedPics/2319.png
#   inflating: face-detection/data/convertedPics/2322.png
#   inflating: face-detection/data/convertedPics/2325.png
#   inflating: face-detection/data/convertedPics/2329.png
#   inflating: face-detection/data/convertedPics/2332.png
#   inflating: face-detection/data/convertedPics/2335.png
#   inflating: face-detection/data/convertedPics/2339.png
#   inflating: face-detection/data/convertedPics/2340.png
#   inflating: face-detection/data/convertedPics/2341.png
#   inflating: face-detection/data/convertedPics/2344.png
#   inflating: face-detection/data/convertedPics/2346.png
#   inflating: face-detection/data/convertedPics/2352.png
#   inflating: face-detection/data/convertedPics/2353.png
#   inflating: face-detection/data/convertedPics/2354.png
#   inflating: face-detection/data/convertedPics/2355.png
#   inflating: face-detection/data/convertedPics/2356.png
#   inflating: face-detection/data/convertedPics/2362.png
#   inflating: face-detection/data/convertedPics/2364.png
#   inflating: face-detection/data/convertedPics/2365.png
#   inflating: face-detection/data/convertedPics/2369.png
#   inflating: face-detection/data/convertedPics/2370.png
#   inflating: face-detection/data/convertedPics/2377.png
#   inflating: face-detection/data/convertedPics/2380.png
#   inflating: face-detection/data/convertedPics/2382.png
#   inflating: face-detection/data/convertedPics/2383.png
#   inflating: face-detection/data/convertedPics/2385.png
#   inflating: face-detection/data/convertedPics/2387.png
#   inflating: face-detection/data/convertedPics/2388.png
#   inflating: face-detection/data/convertedPics/2389.png
#   inflating: face-detection/data/convertedPics/2390.png
#   inflating: face-detection/data/convertedPics/2391.png
#   inflating: face-detection/data/convertedPics/2394.png
#   inflating: face-detection/data/convertedPics/2395.png
#   inflating: face-detection/data/convertedPics/2399.png
#   inflating: face-detection/data/convertedPics/2402.png
#   inflating: face-detection/data/convertedPics/2405.png
#   inflating: face-detection/data/convertedPics/2407.png
#   inflating: face-detection/data/convertedPics/2408.png
#   inflating: face-detection/data/convertedPics/2409.png
#   inflating: face-detection/data/convertedPics/2412.png
#   inflating: face-detection/data/convertedPics/2413.png
#   inflating: face-detection/data/convertedPics/2416.png
#   inflating: face-detection/data/convertedPics/2418.png
#   inflating: face-detection/data/convertedPics/2419.png
#   inflating: face-detection/data/convertedPics/2420.png
#   inflating: face-detection/data/convertedPics/2424.png
#   inflating: face-detection/data/convertedPics/2425.png
#   inflating: face-detection/data/convertedPics/2427.png
#   inflating: face-detection/data/convertedPics/2430.png
#   inflating: face-detection/data/convertedPics/2431.png
#   inflating: face-detection/data/convertedPics/2432.png
#   inflating: face-detection/data/convertedPics/2434.png
#   inflating: face-detection/data/convertedPics/2436.png
#   inflating: face-detection/data/convertedPics/2438.png
#   inflating: face-detection/data/convertedPics/2439.png
#   inflating: face-detection/data/convertedPics/2443.png
#   inflating: face-detection/data/convertedPics/2448.png
#   inflating: face-detection/data/convertedPics/2450.png
#   inflating: face-detection/data/convertedPics/2451.png
#   inflating: face-detection/data/convertedPics/2452.png
#   inflating: face-detection/data/convertedPics/2453.png
#   inflating: face-detection/data/convertedPics/2465.png
#   inflating: face-detection/data/convertedPics/2469.png
#   inflating: face-detection/data/convertedPics/2470.png
#   inflating: face-detection/data/convertedPics/2472.png
#   inflating: face-detection/data/convertedPics/2475.png
#   inflating: face-detection/data/convertedPics/2477.png
#   inflating: face-detection/data/convertedPics/2484.png
#   inflating: face-detection/data/convertedPics/2487.png
#   inflating: face-detection/data/convertedPics/2490.png
#   inflating: face-detection/data/convertedPics/2492.png
#   inflating: face-detection/data/convertedPics/2496.png
#   inflating: face-detection/data/convertedPics/2497.png
#   inflating: face-detection/data/convertedPics/2499.png
#   inflating: face-detection/data/convertedPics/2501.png
#   inflating: face-detection/data/convertedPics/2502.png
#   inflating: face-detection/data/convertedPics/2505.png
#   inflating: face-detection/data/convertedPics/2506.png
#   inflating: face-detection/data/convertedPics/2508.png
#   inflating: face-detection/data/convertedPics/2511.png
#   inflating: face-detection/data/convertedPics/2512.png
#   inflating: face-detection/data/convertedPics/2516.png
#   inflating: face-detection/data/convertedPics/2520.png
#   inflating: face-detection/data/convertedPics/2525.png
#   inflating: face-detection/data/convertedPics/2528.png
#   inflating: face-detection/data/convertedPics/2530.png
#   inflating: face-detection/data/convertedPics/2531.png
#   inflating: face-detection/data/convertedPics/2535.png
#   inflating: face-detection/data/convertedPics/2536.png
#   inflating: face-detection/data/convertedPics/2540.png
#   inflating: face-detection/data/convertedPics/2543.png
#   inflating: face-detection/data/convertedPics/2546.png
#   inflating: face-detection/data/convertedPics/2549.png
#   inflating: face-detection/data/convertedPics/2550.png
#   inflating: face-detection/data/convertedPics/2552.png
#   inflating: face-detection/data/convertedPics/2555.png
#   inflating: face-detection/data/convertedPics/2557.png
#   inflating: face-detection/data/convertedPics/2558.png
#   inflating: face-detection/data/convertedPics/2559.png
#   inflating: face-detection/data/convertedPics/2562.png
#   inflating: face-detection/data/convertedPics/2564.png
#   inflating: face-detection/data/convertedPics/2566.png
#   inflating: face-detection/data/convertedPics/2567.png
#   inflating: face-detection/data/convertedPics/2568.png
#   inflating: face-detection/data/convertedPics/2569.png
#   inflating: face-detection/data/convertedPics/2572.png
#   inflating: face-detection/data/convertedPics/2574.png
#   inflating: face-detection/data/convertedPics/2575.png
#   inflating: face-detection/data/convertedPics/2576.png
#   inflating: face-detection/data/convertedPics/2579.png
#   inflating: face-detection/data/convertedPics/2583.png
#   inflating: face-detection/data/convertedPics/2584.png
#   inflating: face-detection/data/convertedPics/2585.png
#   inflating: face-detection/data/convertedPics/2586.png
#   inflating: face-detection/data/convertedPics/2587.png
#   inflating: face-detection/data/convertedPics/2590.png
#   inflating: face-detection/data/convertedPics/2592.png
#   inflating: face-detection/data/convertedPics/2593.png
#   inflating: face-detection/data/convertedPics/2596.png
#   inflating: face-detection/data/convertedPics/2598.png
#   inflating: face-detection/data/convertedPics/2600.png
#   inflating: face-detection/data/convertedPics/2601.png
#   inflating: face-detection/data/convertedPics/2602.png
#   inflating: face-detection/data/convertedPics/2603.png
#   inflating: face-detection/data/convertedPics/2604.png
#   inflating: face-detection/data/convertedPics/2605.png
#   inflating: face-detection/data/convertedPics/2609.png
#   inflating: face-detection/data/convertedPics/2610.png
#   inflating: face-detection/data/convertedPics/2611.png
#   inflating: face-detection/data/convertedPics/2613.png
#   inflating: face-detection/data/convertedPics/2614.png
#   inflating: face-detection/data/convertedPics/2616.png
#   inflating: face-detection/data/convertedPics/2618.png
#   inflating: face-detection/data/convertedPics/2622.png
#   inflating: face-detection/data/convertedPics/2629.png
#   inflating: face-detection/data/convertedPics/2630.png
#   inflating: face-detection/data/convertedPics/2632.png
#   inflating: face-detection/data/convertedPics/2637.png
#   inflating: face-detection/data/convertedPics/2638.png
#   inflating: face-detection/data/convertedPics/2641.png
#   inflating: face-detection/data/convertedPics/2642.png
#   inflating: face-detection/data/convertedPics/2643.png
#   inflating: face-detection/data/convertedPics/2644.png
#   inflating: face-detection/data/convertedPics/2645.png
#   inflating: face-detection/data/convertedPics/2646.png
#   inflating: face-detection/data/convertedPics/2648.png
#   inflating: face-detection/data/convertedPics/2671.png
#   inflating: face-detection/data/convertedPics/2676.png
#   inflating: face-detection/data/convertedPics/2682.png
#   inflating: face-detection/data/convertedPics/2687.png
#   inflating: face-detection/data/convertedPics/2689.png
#   inflating: face-detection/data/convertedPics/2695.png
#   inflating: face-detection/data/convertedPics/2697.png
#   inflating: face-detection/data/convertedPics/2698.png
#   inflating: face-detection/data/convertedPics/2702.png
#   inflating: face-detection/data/convertedPics/2703.png
#   inflating: face-detection/data/convertedPics/2704.png
#   inflating: face-detection/data/convertedPics/2706.png
#   inflating: face-detection/data/convertedPics/2708.png
#   inflating: face-detection/data/convertedPics/2710.png
#   inflating: face-detection/data/convertedPics/2711.png
#   inflating: face-detection/data/convertedPics/2712.png
#   inflating: face-detection/data/convertedPics/2713.png
#   inflating: face-detection/data/convertedPics/2714.png
#   inflating: face-detection/data/convertedPics/2715.png
#   inflating: face-detection/data/convertedPics/2716.png
#   inflating: face-detection/data/convertedPics/2718.png
#   inflating: face-detection/data/convertedPics/2720.png
#   inflating: face-detection/data/convertedPics/2726.png
#   inflating: face-detection/data/convertedPics/2727.png
#   inflating: face-detection/data/convertedPics/2736.png
#   inflating: face-detection/data/convertedPics/2748.png
#   inflating: face-detection/data/convertedPics/2752.png
#   inflating: face-detection/data/convertedPics/2753.png
#   inflating: face-detection/data/convertedPics/2754.png
#   inflating: face-detection/data/convertedPics/2755.png
#   inflating: face-detection/data/convertedPics/2757.png
#   inflating: face-detection/data/convertedPics/2764.png
#   inflating: face-detection/data/convertedPics/2765.png
#   inflating: face-detection/data/convertedPics/2766.png
#   inflating: face-detection/data/convertedPics/2770.png
#   inflating: face-detection/data/convertedPics/2771.png
#   inflating: face-detection/data/convertedPics/2774.png
#   inflating: face-detection/data/convertedPics/2776.png
#   inflating: face-detection/data/convertedPics/2778.png
#   inflating: face-detection/data/convertedPics/2779.png
#   inflating: face-detection/data/convertedPics/2780.png
#   inflating: face-detection/data/convertedPics/2781.png
#   inflating: face-detection/data/convertedPics/2784.png
#   inflating: face-detection/data/convertedPics/2790.png
#   inflating: face-detection/data/convertedPics/2792.png
#   inflating: face-detection/data/convertedPics/2798.png
#   inflating: face-detection/data/convertedPics/2799.png
#   inflating: face-detection/data/convertedPics/2804.png
#   inflating: face-detection/data/convertedPics/2806.png
#   inflating: face-detection/data/convertedPics/2811.png
#   inflating: face-detection/data/convertedPics/2813.png
#   inflating: face-detection/data/convertedPics/2814.png
#   inflating: face-detection/data/convertedPics/2816.png
#   inflating: face-detection/data/convertedPics/2823.png
#   inflating: face-detection/data/convertedPics/2824.png
#   inflating: face-detection/data/convertedPics/2826.png
#   inflating: face-detection/data/convertedPics/2827.png
#   inflating: face-detection/data/convertedPics/2830.png
#   inflating: face-detection/data/convertedPics/2832.png
#   inflating: face-detection/data/convertedPics/2834.png
#   inflating: face-detection/data/convertedPics/2836.png
#   inflating: face-detection/data/convertedPics/2839.png
#   inflating: face-detection/data/convertedPics/2841.png
#   inflating: face-detection/data/val_fnames.csv
#   inflating: face-detection/data/val_bboxes.pkl
#   inflating: face-detection/data/train_fnames.csv
#   inflating: face-detection/data/train_bboxes.pkl
#   inflating: face-detection/data/test_fnames.csv
#   inflating: face-detection/data/test_bboxes.pkl
#    creating: face-detection/data/checkpoints/

# %%
cd /content/face-detection
# Out:
# /content/face-detection

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 101kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.18.2)
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.1.0

# %%
from get_data import load_dataset, unpack

# %% [markdown]
# In this task we use processed [FDDB dataset](http://vis-www.cs.umass.edu/fddb/). Processing defined in file [./prepare_data.ipynb](prepare_data.ipynb) and consists of:
#
# 1. Extract bboxes from dataset. In base dataset face defined by [ellipsis](http://vis-www.cs.umass.edu/fddb/samples/) that not very useful for basic neural network learning.
# 2. Remove images with big and small faces on one shoot.
# 3. Re-size images to bounding boxes (bboxes) have same size 32 +/- pixels.
#
# Each image in train, validation and test datasets have shape (176, 176, 3), but part of this image is black background. Interesting image aligned at top left corner.
#
# Bounding boxes define face in image and consist of 5 integer numbers: [image_index, min_row, min_col, max_row, max_col]. Bounding box width and height are 32 +/- 8 pixels wide.
#
# `train_bboxes` and `val_bboxes` is a list of bboxes.
#
# `train_shapes` and `val_shapes` is a list of interesting image shapes.

# %%
# First run will download 30 MB data from github

train_images, train_bboxes, train_shapes = load_dataset("data", "train")
val_images, val_bboxes, val_shapes = load_dataset("data", "val")

# %%
train_images[0].shape, len(train_bboxes), train_bboxes[0], print(train_shapes[0])
# Out:
# [65 68]
# ((176, 176, 3), 1051, array([ 0,  6, 27, 42, 54], dtype=int32), None)

# %%
val_images[0].shape
# Out:
# (176, 176, 3)

# %% [markdown]
# ## Prepare data (1 point)
#
# For learning we should extract positive and negative samples from image.
# Positive and negative samples counts should be similar.
# Every samples should have same size.

# %%
from graph import visualize_bboxes
visualize_bboxes(images=train_images,
                 true_bboxes=train_bboxes
                )

# %% [markdown]
# Every image can represent multiple faces, so we should extract all faces from every images and crop them to `SAMPLE_SHAPE`. This set of extracted images are named `positive`.
#
# Then we chould extract `negative` set. This images should have `SAMPLE_SHAPE` size. Pseudocode for extracting:
#
#     negative_collection := []
#
#     for i in range(negative_bbox_count):
#         Select random image.
#         image_shape := image_shapes[image_index]
#         image_true_bboxes := true_bboxes[true_bboxes[:, 0] == image_index, 1:]
#
#         for j in TRY_COUNT: # TRY_COUNT is a magic constant, for example, 100
#             Generate new_bbox within image_shape.
#
#             if new_bbox is negative bbox for image_true_bboxes:
#                 Extract from image, new_bbox and resize to SAMPLE_SIZE negative_sample.
#                 Add negative sample to negative_collection.
#                 Break # for j in TRY_COUNT

# %%
SAMPLE_SHAPE = (32, 32, 3)

# %%
from scores import iou_score # https://en.wikipedia.org/wiki/Jaccard_index

def is_negative_bbox(new_bbox, true_bboxes, eps=1e-1):
    """Check if new bbox not in true bbox list.
    
    There bbox is 4 ints [min_row, min_col, max_row, max_col] without image index."""
    for bbox in true_bboxes:
        if iou_score(new_bbox, bbox) >= eps:
            return False
    return True

# %%
# Write this function
def gen_negative_bbox(image_shape, bbox_size, true_bboxes):
    """Generate negative bbox for image."""
    height, width = bbox_size
    min_row = np.random.choice(image_shape[0] - height)
    max_row = min_row + height
    min_col = np.random.choice(image_shape[1] - width)
    max_col = min_col + width
    return [min_row, min_col, max_row, max_col]

def get_positive_negative(images, true_bboxes, image_shapes, negative_bbox_count=None):
    """Retrieve positive and negative samples from image."""
    positive = []
    negative = []
    image_count = image_shapes.shape[0]
    
    if negative_bbox_count is None:
        negative_bbox_count = len(true_bboxes)
    
    # Pay attention to the fact that most part of image may be black -
    # extract negative samples only from part [0:image_shape[0], 0:image_shape[1]]
    
    # Write code here
    # ...
    for true_bbox in true_bboxes:        
        image_index = true_bbox[0]
        pos_img = images[image_index][true_bbox[1]:true_bbox[1]+32, true_bbox[2]:true_bbox[2]+32, :]
        positive.append(pos_img)
        
    for i in range(negative_bbox_count):
        image_index = np.random.choice(len(images))
        image_shape = image_shapes[image_index]
        image_true_bboxes = true_bboxes[true_bboxes[:, 0] == image_index, 1:]
        for j in range(100):
            #bbox_index = np.random.choice(len(image_true_bboxes))
            #height = image_true_bboxes[bbox_index][2] - image_true_bboxes[bbox_index][0]
            #width = image_true_bboxes[bbox_index][3] - image_true_bboxes[bbox_index][1]
            bbox_size = (32, 32)
            new_bbox = gen_negative_bbox(image_shape, bbox_size, image_true_bboxes)
            if is_negative_bbox(new_bbox, image_true_bboxes):
                neg_img = images[image_index][new_bbox[0]:new_bbox[2], new_bbox[1]:new_bbox[3]]
                #neg_img = skimage.transform.resize(neg_img, SAMPLE_SHAPE, mode='reflect')
                negative.append(neg_img)
                break
   
    return positive, negative

# %%
def get_samples(images, true_bboxes, image_shapes):
    """Usefull samples for learning.
    
    X - positive and negative samples.
    Y - one hot encoded list of zeros and ones. One is positive marker.
    """
    positive, negative = get_positive_negative(images=images, true_bboxes=true_bboxes, 
                                               image_shapes=image_shapes)
    X = positive
    Y = [[0, 1]] * len(positive)
    
    X.extend(negative)
    Y.extend([[1, 0]] * len(negative))
    
    return np.array(X), np.array(Y)

# %% [markdown]
# Now we can extract samples from images.

# %%
X_train, Y_train = get_samples(train_images, train_bboxes, train_shapes)
X_val, Y_val = get_samples(val_images, val_bboxes, val_shapes)

# %%
# There we should see faces
from graph import visualize_samples
visualize_samples(X_train[Y_train[:, 1] == 1])

# %%
# There we shouldn't see faces
visualize_samples(X_train[Y_train[:, 1] == 0])

# %% [markdown]
# ## Classifier training (3 points)
#
# First of all, we should train face classifier that checks if face represented on sample.

# %%
BATCH_SIZE = 64

# %% [markdown]
# ### Image augmentation
#
# Important thing in deep learning is augmentation. Sometimes, if your model are complex and cool, you can increase quality by using good augmentation.
#
# Keras provide good [images preprocessing and augmentation](https://keras.io/preprocessing/image/). This preprocessing executes online (on the fly) while learning.
#
# Of course, if you want using samplewise and featurewise center and std normalization you should run this transformation on predict stage. But you will use this classifier to fully convolution detector, in this case such transformation quite complicated, and we don't recommend use them in classifier.
#
# For heavy augmentation you can use library [imgaug](https://github.com/aleju/imgaug). If you need, you can use this library in offline manner (simple way) and online manner (hard way). However, hard way is not so hard: you only have to write [python generator](https://wiki.python.org/moin/Generators), which returns image batches, and pass it to [fit_generator](https://keras.io/models/model/#fit_generator)

# %%
from keras.preprocessing.image import ImageDataGenerator # Usefull thing. Read the doc.

datagen = ImageDataGenerator(horizontal_flip=True,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.1,
                             samplewise_center = True,
                             samplewise_std_normalization = True
                            )
datagen.fit(X_train)

# %%
X_train.shape
# Out:
# (1951, 32, 32, 3)

# %% [markdown]
# ### Fitting classifier
#
# For fitting you can use one of Keras optimizer algorithms. [Good overview](http://ruder.io/optimizing-gradient-descent/)
#
# To choose best learning rate strategy you should read about EarlyStopping and ReduceLROnPlateau or LearningRateScheduler on [callbacks](https://keras.io/callbacks/) page of keras documentation, it's very useful in deep learning.
#
# If you repeat architecture from some paper, you can find information about good optimizer algorithm and learning rate strategy in this paper. For example, every [keras application](https://keras.io/applications/) has link to paper, that describes suitable learning procedure for this specific architecture.

# %%
import os.path
from keras.optimizers import Adam
# Very usefull, pay attention
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler

from graph import plot_history


def fit(model, datagen, X_train, Y_train, X_val, Y_val, model_name=None, output_dir="data/checkpoints", class_weight=None, epochs=50, lr=0.001, verbose=False):
    """Fit model.
    
    You can edit this function anyhow.
    """
    
    if verbose:
        model.summary()

    model.compile(optimizer=Adam(lr=lr), # You can use another optimizer
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    
    history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
                                  validation_data=(datagen.standardize(X_val), Y_val),
                                  epochs=epochs, steps_per_epoch=len(X_train) // BATCH_SIZE,
                                  callbacks=[ModelCheckpoint(os.path.join(output_dir, "{model_name}").format(model_name=model_name) + "-{epoch:02d}-{val_loss:.2f}.hdf5", save_best_only=True),
                                            ] if model_name is not None else [],
                                  class_weight=class_weight,
                      
                                 )  # starts training
    
    plot_history(history)

# %% [markdown]
# #### (first point out of three)
#
# ![lenet architecture](lenet_architecture.png)
# LeCun, Y., Bottou, L., Bengio, Y. and Haffner, P., 1998. Gradient-based learning applied to document recognition. Proceedings of the IEEE, 86(11), pp.2278-2324.
#
# Of course, you can use any another architecture, if want. Main thing is classification quality of your model.
#
# Acceptable validation accuracy for this task is 0.92.

# %%
from keras.models import Model, Sequential
from keras.layers import Flatten, Dense, Activation, Input, Dropout, Activation, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D

def generate_model(sample_shape):
    # Classification model
    # You can start from LeNet architecture
    x = inputs = Input(shape=sample_shape)

    # Write code here
    # ...
    x = Conv2D(32, (5, 5), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (5, 5), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.25)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.25)(x)

    # This creates a model
    predictions = Dense(2, activation='softmax')(x)
    return Model(inputs=inputs, outputs=predictions)

model = generate_model(SAMPLE_SHAPE)

# %% [markdown]
# #### Fit the model (second point out of three)
#
# If you doesn't have fast video-card suitable for deep learning, you can first check neural network modifications with small value of parameter `epochs`, for example, 10, and then after selecting best model increase this parameter.
# Fitting on CPU can be long, we suggest do it at bedtime.
#
# Don't forget change model name.

# %%
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 298,722
# Trainable params: 298,722
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')

# %%
import scipy.interpolate

# %%
# Attention: Windows implementation may cause an error here. In that case use model_name=None.
fit(model_name="mymodel", model=model, datagen=datagen, X_train=X_train, X_val=X_val, Y_train=Y_train, Y_val=Y_val)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 1s 49ms/step - loss: 0.4701 - acc: 0.7768 - val_loss: 0.2572 - val_acc: 0.8976
# Epoch 2/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.3353 - acc: 0.8634 - val_loss: 0.2198 - val_acc: 0.9159
# Epoch 3/50
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2890 - acc: 0.8874 - val_loss: 0.1872 - val_acc: 0.9312
# Epoch 4/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.2765 - acc: 0.8843 - val_loss: 0.2003 - val_acc: 0.9373
# Epoch 5/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.2237 - acc: 0.9156 - val_loss: 0.1682 - val_acc: 0.9373
# Epoch 6/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.2077 - acc: 0.9197 - val_loss: 0.1660 - val_acc: 0.9404
# Epoch 7/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.2034 - acc: 0.9176 - val_loss: 0.1508 - val_acc: 0.9419
# Epoch 8/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1721 - acc: 0.9343 - val_loss: 0.1212 - val_acc: 0.9541
# Epoch 9/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1575 - acc: 0.9406 - val_loss: 0.1142 - val_acc: 0.9511
# Epoch 10/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1322 - acc: 0.9504 - val_loss: 0.0979 - val_acc: 0.9648
# Epoch 11/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1259 - acc: 0.9530 - val_loss: 0.0938 - val_acc: 0.9602
# Epoch 12/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1192 - acc: 0.9583 - val_loss: 0.0918 - val_acc: 0.9664
# Epoch 13/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1042 - acc: 0.9651 - val_loss: 0.0675 - val_acc: 0.9771
# Epoch 14/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0760 - acc: 0.9750 - val_loss: 0.1253 - val_acc: 0.9465
# Epoch 15/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1292 - acc: 0.9530 - val_loss: 0.1043 - val_acc: 0.9480
# Epoch 16/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0967 - acc: 0.9589 - val_loss: 0.1063 - val_acc: 0.9618
# Epoch 17/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1065 - acc: 0.9593 - val_loss: 0.0974 - val_acc: 0.9602
# Epoch 18/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0904 - acc: 0.9677 - val_loss: 0.0715 - val_acc: 0.9679
# Epoch 19/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1145 - acc: 0.9604 - val_loss: 0.1158 - val_acc: 0.9618
# Epoch 20/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0957 - acc: 0.9625 - val_loss: 0.0670 - val_acc: 0.9740
# Epoch 21/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0776 - acc: 0.9729 - val_loss: 0.0608 - val_acc: 0.9740
# Epoch 22/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0790 - acc: 0.9765 - val_loss: 0.0664 - val_acc: 0.9755
# Epoch 23/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0747 - acc: 0.9713 - val_loss: 0.0645 - val_acc: 0.9755
# Epoch 24/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0727 - acc: 0.9760 - val_loss: 0.0783 - val_acc: 0.9694
# Epoch 25/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0788 - acc: 0.9703 - val_loss: 0.0708 - val_acc: 0.9771
# Epoch 26/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0670 - acc: 0.9807 - val_loss: 0.0679 - val_acc: 0.9694
# Epoch 27/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0735 - acc: 0.9718 - val_loss: 0.0744 - val_acc: 0.9694
# Epoch 28/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0745 - acc: 0.9744 - val_loss: 0.0734 - val_acc: 0.9694
# Epoch 29/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0664 - acc: 0.9765 - val_loss: 0.0699 - val_acc: 0.9740
# Epoch 30/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0651 - acc: 0.9755 - val_loss: 0.0716 - val_acc: 0.9755
# Epoch 31/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0628 - acc: 0.9781 - val_loss: 0.0737 - val_acc: 0.9725
# Epoch 32/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0649 - acc: 0.9745 - val_loss: 0.0774 - val_acc: 0.9725
# Epoch 33/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0560 - acc: 0.9786 - val_loss: 0.0760 - val_acc: 0.9694
# Epoch 34/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0580 - acc: 0.9818 - val_loss: 0.0562 - val_acc: 0.9832
# Epoch 35/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0427 - acc: 0.9849 - val_loss: 0.0602 - val_acc: 0.9786
# Epoch 36/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0581 - acc: 0.9802 - val_loss: 0.0552 - val_acc: 0.9801
# Epoch 37/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0524 - acc: 0.9776 - val_loss: 0.0604 - val_acc: 0.9786
# Epoch 38/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0502 - acc: 0.9802 - val_loss: 0.0624 - val_acc: 0.9740
# Epoch 39/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0569 - acc: 0.9776 - val_loss: 0.0734 - val_acc: 0.9725
# Epoch 40/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0497 - acc: 0.9792 - val_loss: 0.0705 - val_acc: 0.9786
# Epoch 41/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0342 - acc: 0.9865 - val_loss: 0.0966 - val_acc: 0.9648
# Epoch 42/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0609 - acc: 0.9771 - val_loss: 0.0670 - val_acc: 0.9771
# Epoch 43/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0573 - acc: 0.9781 - val_loss: 0.0625 - val_acc: 0.9771
# Epoch 44/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0497 - acc: 0.9807 - val_loss: 0.0585 - val_acc: 0.9817
# Epoch 45/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0325 - acc: 0.9880 - val_loss: 0.0718 - val_acc: 0.9817
# Epoch 46/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0661 - acc: 0.9760 - val_loss: 0.0669 - val_acc: 0.9740
# Epoch 47/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0440 - acc: 0.9869 - val_loss: 0.0621 - val_acc: 0.9847
# Epoch 48/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0425 - acc: 0.9885 - val_loss: 0.0888 - val_acc: 0.9709
# Epoch 49/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0436 - acc: 0.9828 - val_loss: 0.0717 - val_acc: 0.9725
# Epoch 50/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0399 - acc: 0.9849 - val_loss: 0.0539 - val_acc: 0.9817

# %% [markdown]
# #### (third point out of three)
#
# After learning model weights saves in folder `data/checkpoints/`.
# Use `model.load_weights(fname)` to load best weights.
#
# If you use Windows and Model Checkpoint doesn't work on your configuration, you should implement [your own Callback](https://keras.io/callbacks/#create-a-callback) to save best weights in memory and then load it back.

# %%
def get_checkpoint():
    return "data/checkpoints/mymodel-24-0.06.hdf5"

model.load_weights(get_checkpoint())

# %% [markdown]
# ## Detection
#
# If you have prepared classification architecture with high validation score, you can use this architecture for detection.
#
# Convert classification architecture to fully convolution neural network (FCNN), that returns heatmap of activation.
#
# ### Detector model or sliding window (1 point)
#
# Now you should replace fully-connected layers with $1 \times 1$ convolution layers.
#
# Every fully connected layer perform operation $f(Wx + b)$, where $f(\cdot)$ is nonlinear activation function, $x$ is layer input, $W$ and $b$ is layer weights. This operation can be emulated with $1 \times 1$ convolution with activation function $f(\cdot)$, that perform exactly same operation $f(Wx + b)$.
#
# If there is `Flatten` layer with $n \times k$ input size before fully connected layers, convolution should have same $n \times k$ input size.
# Multiple fully connected layers can be replaced with convolution layers sequence.
#
# After replace all fully connected layers with convolution layers, we get fully convolution network. If input shape is equal to input size of previous network, output will have size $1 \times 1$. But if we increase input shape, output shape automatically will be increased. For example, if convolution step of previous network strides 4 pixels, increase input size with 100 pixels along all axis makes increase outputsize with 25 values along all axis. We got activation map of classifier without necessary extract samples from image and multiple calculate low-level features.
#
# In total:
# 1. $1 \times 1$ convolution layer is equivalent of fully connected layer.
# 2. $1 \times 1$ convolution layers can be used to get activation map of classification network in "sliding window" manner.
#
# We propose replace last fully connected layer with softmax actiovation to convolution layer with linear activation.It will be usefull to find good treshold. Of course, you can use softmax activation.
#
# #### Example of replace cnn head:
#
# ##### Head before convert
#
# ![before replace image](before_convert.png)
#
# ##### Head after convert
#
# ![before replace image](after_convert.png)
#
# On this images displayed only head. `InputLayer` should be replaced with convolution part exit.
# Before convert network head takes fifty $8 \times 8$ feature maps and returns two values: probability of negative and positive classes. This output can be considered as activation map with size $1 \times 1$.
#
# If input have size $8 \times 8$, output after convert would have $1 \times 1$ size, but input size is $44 \times 44$.
# After convert network head returns one $37 \times 37$ activation map.

# %%
# FCNN

IMAGE_SHAPE = (176, 176, 3)

def generate_fcnn_model(image_shape):
    """After model compilation input size cannot be changed.
    
    So, we need create a function to have ability to change size later.
    """
    x = inputs = Input(image_shape)

    # Write code here
    # ...
    x = Conv2D(32, (5, 5), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (5, 5), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (8, 8), activation='relu')(x)
    x = Dropout(0.25)(x)
    x = Conv2D(64, (1, 1), activation='relu')(x)
    x = Dropout(0.25)(x)

    # This creates a model
    predictions = Conv2D(2, (1, 1), activation='linear')(x)
    return Model(inputs=inputs, outputs=predictions)

fcnn_model = generate_fcnn_model(IMAGE_SHAPE)

# %%
print(fcnn_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 176, 176, 3)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 176, 176, 32)      2432
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 88, 88, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 88, 88, 32)        25632
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 44, 44, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 37, 37, 128)       262272
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 37, 37, 64)        8256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 37, 37, 2)         130
# =================================================================
# Total params: 298,722
# Trainable params: 298,722
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### (1 point)
#
# Then you should write function that copy weights from classification model to fully convolution model.
# Convolution weights may be copied without modification, fully-connected layer weights should be reshaped before copy.
#
# Pay attention to last layer.

# %%
def copy_weights(base_model, fcnn_model):
    """Set FCNN weights from base model.
    """
    
    new_fcnn_weights = []
    prev_fcnn_weights = fcnn_model.get_weights()
    prev_base_weights = base_model.get_weights()
    
    # Write code here
    # ...
    for prev_fcnn_weight, prev_base_weight in zip(prev_fcnn_weights, prev_base_weights):
        new_fcnn_weights.append(prev_base_weight.reshape(prev_fcnn_weight.shape))
        
        
    fcnn_model.set_weights(new_fcnn_weights)

copy_weights(base_model=model, fcnn_model=fcnn_model)

# %% [markdown]
# ### Model visualization

# %%
from graph import visualize_heatmap

# %%
predictions = fcnn_model.predict(np.array(val_images))
visualize_heatmap(val_images, predictions[:, :, :, 1])

# %% [markdown]
# ### Detector (1 point)
#
# First detector part is getting bboxes and decision function.
# Greater decision function indicates better detector confidence.
#
# This function should return pred_bboxes and decision_function:
#
# - `pred bboxes` is list of 5 int tuples like `true bboxes`: `[image_index, min_row, min_col, max_row, max_col]`.
# - `decision function` is confidence of detector for every pred bbox: list of float values, `len(decision function) == len(pred bboxes)`
#
# We propose resize image to `IMAGE_SHAPE` size, find faces on resized image with `SAMPLE_SHAPE` size and then resize them back.

# %%
# Detection
from skimage.feature import peak_local_max

def get_bboxes_and_decision_function(fcnn_model, images, image_shapes):      
    cropped_images = np.array([transform.resize(image, IMAGE_SHAPE, mode="reflect")  if image.shape != IMAGE_SHAPE else image for image in images])
    pred_bboxes, decision_function = [], []
   
    # Predict
    predictions = fcnn_model.predict(datagen.standardize(np.asarray(cropped_images,dtype='float')))

    # Write code here
    # ...
    for i in range(len(predictions)):
        img_shape = image_shapes[i]
        local_max_list = peak_local_max(predictions[i][:,:,1], num_peaks=5, min_distance=3, exclude_border=False)
        for local_max_orig in local_max_list:
            local_max = ((local_max_orig + 2)*176/37).astype(int)
            
            if local_max[0] < img_shape[0] and local_max[1] < img_shape[1]:
                bbox = [i] + [local_max[0]-16,local_max[1]-16,local_max[0]+16,local_max[1]+16]
                
                pred_bboxes.append(bbox)
                decision_function.append(predictions[i, local_max_orig[0], local_max_orig[1], 1])
        
    return pred_bboxes, decision_function

# %% [markdown]
# #### Detector visualization

# %%
pred_bboxes, decision_function = get_bboxes_and_decision_function(fcnn_model=fcnn_model, images=val_images, image_shapes=val_shapes)

visualize_bboxes(images=val_images,
                 pred_bboxes=pred_bboxes,
                 true_bboxes=val_bboxes,
                 decision_function=decision_function
                )

# %% [markdown]
# ## Detector score (1 point)
#
# Write [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall) graph.
#
# You can use function `best_match` to extract matching between prediction and ground truth, false positive and false negative samples. Pseudo-code for calculation precision and recall graph:
#
#     # Initialization for first step threshold := -inf
#     tn := 0 # We haven't any positive sample
#     fn := |false_negative| # But some faces wasn't been detected
#     tp := |true_bboxes| # All true bboxes have been caught
#     fp := |false_positive| # But also some false positive samples have been caught
#
#     Sort decision_function and pred_bboxes with order defined by decision_function
#     y_true := List of answers for "Is the bbox have matching in y_true?" for every bbox in pred_bboxes
#
#     for y_on_this_step in y_true:
#         # Now we increase threshold, so some predicted bboxes makes positive.
#         # If y_t is True then the bbox is true positive else bbox is false positive
#         # So we should
#         Update tp, tn, fp, fn with attention to y_on_this_step
#
#         Add precision and recall point calculated by formula through tp, tn, fp, fn on this step
#         Threshold for this point is decision function on this step.

# %%
from scores import best_match
from graph import plot_precision_recall

def precision_recall_curve(pred_bboxes, true_bboxes, decision_function):
    precision, recall, thresholds = [], [], []
    
    # Write code here
    threshold = min(decision_function) - 1
    max_th = max(decision_function) + 1
    num_steps = 100
    th_step = (max_th - threshold)/num_steps

    sorted_boxes = [[x]+y for y,x in sorted(zip(pred_bboxes,decision_function),key=lambda pair:pair[1])]
    
    for step in range(num_steps):        
        pred_bboxes_th = [x[1:] for x in sorted_boxes if x[0]>threshold]
        if len(pred_bboxes_th) > 0:
            matched, false_negative, false_positive = best_match(pred_bboxes_th, true_bboxes, decision_function)
        else:
            break
        
        prec = len(matched)/(len(matched)+len(false_positive))
        rec = len(matched)/(len(matched)+len(false_negative))
        
        thresholds.append(threshold)
        recall.append(rec)
        precision.append(prec)
        threshold += th_step
    
    return precision, recall, thresholds

# %%
precision, recall, thresholds = precision_recall_curve(pred_bboxes=pred_bboxes, true_bboxes=val_bboxes, decision_function=decision_function)
plot_precision_recall(precision=precision, recall=recall)

# %% [markdown]
# ### Threshold (1 point)
#
# Next step in detector creating is select threshold for decision_function.
# Every possible threshold presents point on recall-precision graph.
#
# Select threshold for `recall=0.85`.

# %%
def get_threshold(thresholds, recall):
    return thresholds[np.argmax(np.asarray(recall) <= 0.85)]

THRESHOLD = get_threshold(thresholds, recall)

# %%
def detect(fcnn_model, images, image_shapes, threshold, return_decision=True):
    """Get bboxes with decision_function not less then threshold."""
    pred_bboxes, decision_function = get_bboxes_and_decision_function(fcnn_model, images, image_shapes)   
    result, result_decision = [], []
    
    # Write code here
    # ...
    for i in range(len(pred_bboxes)):
        if decision_function[i] >= threshold:
            result.append(pred_bboxes[i])
            result_decision.append(decision_function[i])
    
    if return_decision:
        return result, result_decision
    else:
        return result

# %%
pred_bboxes, decision_function = detect(fcnn_model=fcnn_model, images=val_images, image_shapes=val_shapes, threshold=THRESHOLD, return_decision=True)

visualize_bboxes(images=val_images,
                 pred_bboxes=pred_bboxes,
                 true_bboxes=val_bboxes,
                 decision_function=decision_function
                )

precision, recall, thresholds = precision_recall_curve(pred_bboxes=pred_bboxes, true_bboxes=val_bboxes, decision_function=decision_function)
plot_precision_recall(precision=precision, recall=recall)

# %% [markdown]
# ## Test dataset (1 point)
#
# Last detector preparation step is testing.
#
# Attention: to avoid over-fitting, after testing algorithm you should run [./prepare_data.ipynb](prepare_data.ipynb), and start all fitting from beginning.
#
# Detection score (in graph header) should be 0.85 or greater.

# %%
test_images, test_bboxes, test_shapes = load_dataset("data", "test")

# We test get_bboxes_and_decision_function becouse we want pay attention to all recall values
pred_bboxes, decision_function = get_bboxes_and_decision_function(fcnn_model=fcnn_model, images=test_images, image_shapes=test_shapes)

visualize_bboxes(images=test_images,
                 pred_bboxes=pred_bboxes,
                 true_bboxes=test_bboxes,
                 decision_function=decision_function
                ) 

precision, recall, threshold = precision_recall_curve(pred_bboxes=pred_bboxes, true_bboxes=test_bboxes, decision_function=decision_function)
plot_precision_recall(precision=precision, recall=recall)

# %% [markdown]
# ## Optional tasks
#
# ### Real image dataset
#
# Test your algorithm on original (not scaled) data.
# Visualize bboxes and plot precision-recall curve.

# %%
# First run will download 523 MB data from github

original_images, original_bboxes, original_shapes = load_dataset("data", "original")

# %%
# Write code here
# ...

# %% [markdown]
# ## Hard negative mining
#
# Upgrade the score with [hard negative mining](https://www.reddit.com/r/computervision/comments/2ggc5l/what_is_hard_negative_mining_and_how_is_it/).
#
# A hard negative is when you take that falsely detected patch, and explicitly create a negative example out of that patch, and add that negative to your training set. When you retrain your classifier, it should perform better with this extra knowledge, and not make as many false positives.

# %%
# Write this function
def hard_negative(train_images, image_shapes, train_bboxes, X_val, Y_val, base_model, fcnn_model):
    pass

# %%
hard_negative(train_images=train_images, image_shapes=train_shapes, train_bboxes=train_bboxes, X_val=X_val, Y_val=Y_val, base_model=model, fcnn_model=fcnn_model)

# %%
model.load_weights("data/checkpoints/...")

# %%
copy_weights(base_model=model, fcnn_model=fcnn_model)

pred_bboxes, decision_function = get_bboxes_and_decision_function(fcnn_model=fcnn_model, images=val_images, image_shapes=val_shapes)

visualize_bboxes(images=val_images,
                 pred_bboxes=pred_bboxes,
                 true_bboxes=val_bboxes,
                 decision_function=decision_function
                )

precision, recall, thresholds = precision_recall_curve(pred_bboxes=pred_bboxes, true_bboxes=val_bboxes, decision_function=decision_function)
plot_precision_recall(precision=precision, recall=recall)

# %% [markdown]
# ### Multi scale detector
#
# Write and test detector with [pyramid representation][pyramid].
# [pyramid]: https://en.wikipedia.org/wiki/Pyramid_(image_processing)
#
# 1. Resize images to predefined scales.
# 2. Run detector with different scales.
# 3. Apply non-maximum supression to detection on different scales.
#
# References:
# 1. [E. H. Adelson,C. H. Anderson, J. R. Bergen, P. J. Burt, J. M. Ogden: Pyramid methods in image processing](http://persci.mit.edu/pub_pdfs/RCA84.pdf)
# 2. [PETER J. BURT, EDWARD H. ADELSON: The Laplacian Pyramid as a Compact Image Code](http://persci.mit.edu/pub_pdfs/pyramid83.pdf)

# %%
def multiscale_detector(fcnn_model, images, image_shapes):
    return []

# %% [markdown]
# ### Next  step
#
# Next steps in deep learning detection are R-CNN, Faster R-CNN and SSD architectures.
# This architecture realization is quite complex.
# For this reason the task doesn't cover them, but you can find the articles in the internet.
